# %%
library("patchwork")
data = read.csv("tempuf_30-36_MasineAli.csv")

# %%
colnames(data)
# Out:
#  [1] "Temperature.for.Cap.30...C."      "Ratio.350.nm...330.nm.for.Cap.30"
#  [3] "Temperature.for.Cap.30...C..1"    "X350.nm.for.Cap.30"
#  [5] "Temperature.for.Cap.30...C..2"    "X330.nm.for.Cap.30"
#  [7] "Temperature.for.Cap.31...C."      "Ratio.350.nm...330.nm.for.Cap.31"
#  [9] "Temperature.for.Cap.31...C..1"    "X350.nm.for.Cap.31"
# [11] "Temperature.for.Cap.31...C..2"    "X330.nm.for.Cap.31"
# [13] "Temperature.for.Cap.32...C."      "Ratio.350.nm...330.nm.for.Cap.32"
# [15] "Temperature.for.Cap.32...C..1"    "X350.nm.for.Cap.32"
# [17] "Temperature.for.Cap.32...C..2"    "X330.nm.for.Cap.32"
# [19] "Temperature.for.Cap.34...C."      "Ratio.350.nm...330.nm.for.Cap.34"
# [21] "Temperature.for.Cap.34...C..1"    "X350.nm.for.Cap.34"
# [23] "Temperature.for.Cap.34...C..2"    "X330.nm.for.Cap.34"
# [25] "Temperature.for.Cap.35...C."      "Ratio.350.nm...330.nm.for.Cap.35"
# [27] "Temperature.for.Cap.35...C..1"    "X350.nm.for.Cap.35"
# [29] "Temperature.for.Cap.35...C..2"    "X330.nm.for.Cap.35"
# [31] "Temperature.for.Cap.36...C."      "Ratio.350.nm...330.nm.for.Cap.36"
# [33] "Temperature.for.Cap.36...C..1"    "X350.nm.for.Cap.36"
# [35] "Temperature.for.Cap.36...C..2"    "X330.nm.for.Cap.36"

# %% [markdown]
# # Lysozyme

# %%
# Ratio - 350nm : 330nm
MAXLYS = max(data$Ratio.350.nm...330.nm.for.Cap.34)

plot(x = data$Temperature.for.Cap.34...C., y = data$Ratio.350.nm...330.nm.for.Cap.34/MAXLYS, col="orange",
     type = "l", 
     ylim = c(0.75,1), 
     xlab="Temperature", ylab="Ratio - 350nm : 330nm",
     main="Lysozyme Temperature Spectroscopy")
lines(x = data$Temperature.for.Cap.35...C., y = data$Ratio.350.nm...330.nm.for.Cap.35/MAXLYS, col="red") 
lines(x = data$Temperature.for.Cap.36...C., y = data$Ratio.350.nm...330.nm.for.Cap.36/MAXLYS, col="pink")
# Out:
# Plot with title “Lysozyme Temperature Spectroscopy”

# %%
# Emission of 350nm

Eg1 <- plot(x = data$Temperature.for.Cap.34...C., y = data$X350.nm.for.Cap.34, col="orange",
     type = "l", 
     ylim = c(200,3200),
     xlab="Temperature", ylab="Emission of 350nm",
     main="Lysozyme 350nm Emmission") +
lines(x = data$Temperature.for.Cap.35...C., y = data$X350.nm.for.Cap.35, col="red") +
lines(x = data$Temperature.for.Cap.36...C., y = data$X350.nm.for.Cap.36, col="pink")

# Emission of 330nm

Eg2 <- plot(x = data$Temperature.for.Cap.34...C., y = data$X330.nm.for.Cap.34, col="orange",
     type = "l", 
     ylim = c(200,3200),
     xlab="Temperature", ylab="Emission of 330nm",
     main="Lysozyme 330nm Emmission") + 
lines(x = data$Temperature.for.Cap.35...C., y = data$X330.nm.for.Cap.35, col="red") +
lines(x = data$Temperature.for.Cap.36...C., y = data$X330.nm.for.Cap.36, col="pink")

Eg1 + Eg2
# Out:
# Plot with title “Lysozyme 350nm Emmission”
# integer(0)
# Plot with title “Lysozyme 330nm Emmission”

# %% [markdown]
# # BSA

# %%
MAXBSA = max(data$Ratio.350.nm...330.nm.for.Cap.30)

plot(x = data$Temperature.for.Cap.30...C., y = data$Ratio.350.nm...330.nm.for.Cap.30/MAXBSA,
     type = "l", 
     ylim = c(0.75,1),
     xlab="Temperature", ylab="Ratio - 350nm : 330nm",
     main="BSA Temperature Spectroscopy")
lines(x = data$Temperature.for.Cap.31...C., y = data$Ratio.350.nm...330.nm.for.Cap.31/MAXBSA) 
lines(x = data$Temperature.for.Cap.32...C., y = data$Ratio.350.nm...330.nm.for.Cap.32/MAXBSA)
# Out:
# Plot with title “BSA Temperature Spectroscopy”
